# %% [markdown]
# # 07 Your First Deep Learning Project in Python with Keras Step-By-Step

# %% [markdown]
# #### Source:
#
# This practical is based on the blog post:
#
# https://machinelearningmastery.com/tutorial-first-neural-network-python-keras/
#
# Here we are going to reproduce parts of that post.
# I recommend using Anaconda Python, read the installation guide for it under Unit 7. Use Python 3.x.

# %% [markdown]
# ### Prerequisites:
# Libraries used in this tutorial:
# - keras (now built into TensorFlow)
# - numpy
# - sklearn
# - pydot
#
# External libraries (necessary for visualization):
# - https://graphviz.gitlab.io/download/

# %% [markdown]
# If you set up your machine at home you can remove the cell below

# %%
# !pip install pydot
# !pip install graphviz
# !pip install tensorflow
# Out:
# Requirement already satisfied: pydot in c:\users\ashra\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: pyparsing>=2.1.4 in c:\users\ashra\anaconda3\lib\site-packages (from pydot) (3.0.9)
# Requirement already satisfied: graphviz in c:\users\ashra\anaconda3\lib\site-packages (0.20.1)
# Collecting tensorflow
#   Using cached tensorflow-2.15.0-cp39-cp39-win_amd64.whl (2.1 kB)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.23.4)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.0.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.7.0)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.1)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.26.2)
# Requirement already satisfied: six>=1.12.0 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: packaging in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (21.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.59.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.3.0)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: setuptools in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (63.4.1)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\ashra\anaconda3\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\ashra\anaconda3\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.37.1)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\ashra\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.1.0)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\ashra\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.3)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\ashra\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.28.1)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\ashra\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\ashra\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.24.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\ashra\anaconda3\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.3.4)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\ashra\anaconda3\lib\site-packages (from packaging->tensorflow-intel==2.15.0->tensorflow) (3.0.9)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\ashra\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\ashra\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\ashra\anaconda3\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\ashra\anaconda3\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\ashra\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2022.9.14)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in c:\users\ashra\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.26.11)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\ashra\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.3)
# Requirement already satisfied: charset-normalizer<3,>=2 in c:\users\ashra\anaconda3\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.0.4)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in c:\users\ashra\anaconda3\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\ashra\anaconda3\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# Installing collected packages: tensorflow
# Successfully installed tensorflow-2.15.0

# %% [markdown]
# #### Datasets used
# Please download the following datasets and put them into the folder, where this notebook is located (i.e. your working directory):
# - https://raw.githubusercontent.com/jbrownlee/Datasets/master/pima-indians-diabetes.data.csv
# - http://archive.ics.uci.edu/ml/machine-learning-databases/iris/iris.data
# - https://raw.githubusercontent.com/jbrownlee/Datasets/master/housing.data

# %% [markdown]
# ### Install Tensorflow:

# %%
import tensorflow as tf
from tensorflow import keras

# %%
from numpy import loadtxt
from keras.models import Sequential
from keras.layers import Dense

# For plotting layers import one of these two:
#from keras.utils.vis_utils import plot_model
from tensorflow.keras.utils import plot_model


import pydot
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load the Pima Indian dataset
#
# It is a csv file with ',' as delimiter.

# %%
# load the dataset
dataset = loadtxt('pima-indians-diabetes.data.csv', delimiter=',')

# %% [markdown]
# The variables can be summarized as follows:
#
# Input Variables (X):
#
# 1. Number of times pregnant
# 2. Plasma glucose concentration a 2 hours in an oral glucose tolerance test
# 3. Diastolic blood pressure (mm Hg)
# 4. Triceps skin fold thickness (mm)
# 5. 2-Hour serum insulin (mu U/ml)
# 6. Body mass index (weight in kg/(height in m)^2)
# 7. Diabetes pedigree function
# 8. Age (years)
#
# Output Variables (Y):
#
# 1. Class variable (0 or 1)

# %% [markdown]
# # Task 0
# What is the size of this dataset? Take a look at a few rows of this dataset to make sure you understand the structure of the data.

# %%
# Separate the dataset into input (X) and output (Y) variables
X = dataset[:,0:8]
Y = dataset[:,8]

# %% [markdown]
# - The model expects rows of data with 8 variables (the input_dim=8 argument)
# - The first hidden layer has 12 nodes and uses the relu activation function.
# - The second hidden layer has 8 nodes and uses the relu activation function.
# - The output layer has one node and uses the sigmoid activation function.

# %%
# define the Keras model
model = Sequential()
model.add(Dense(12, input_dim=8, activation='relu'))
model.add(Dense(8, activation='relu'))
#model.add(Dense(1, activation='sigmoid'))
model.add(Dense(1, activation='sigmoid'))
# Out:
# WARNING:tensorflow:From C:\Users\ashra\anaconda3\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.

# %%
#Check your model 
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 12)                108
#
#  dense_1 (Dense)             (None, 8)                 104
#
#  dense_2 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 221 (884.00 Byte)
# Trainable params: 221 (884.00 Byte)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# To train a neural network model you will need to specify a loss function, an optimizer, and some metrics for monitoring.
#
# https://www.tensorflow.org/guide/keras/train_and_evaluate/

# %%
# compile the Keras model
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# Out:
# WARNING:tensorflow:From C:\Users\ashra\anaconda3\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
# fit the Keras model on the dataset
history = model.fit(X, Y, epochs=150, batch_size=10)
# Out:
# Epoch 1/150
# WARNING:tensorflow:From C:\Users\ashra\anaconda3\lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\ashra\anaconda3\lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 77/77 [==============================] - 1s 2ms/step - loss: 15.3783 - accuracy: 0.6510
# Epoch 2/150
# 77/77 [==============================] - 0s 2ms/step - loss: 1.3227 - accuracy: 0.5247
# Epoch 3/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.9338 - accuracy: 0.5625
# Epoch 4/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.8205 - accuracy: 0.5677
# Epoch 5/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7497 - accuracy: 0.5872
# Epoch 6/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7508 - accuracy: 0.5898
# Epoch 7/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7123 - accuracy: 0.6029
# Epoch 8/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.7155 - accuracy: 0.6315
# Epoch 9/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6794 - accuracy: 0.6380
# Epoch 10/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6679 - accuracy: 0.6471
# Epoch 11/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6469 - accuracy: 0.6771
# Epoch 12/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6462 - accuracy: 0.6562
# Epoch 13/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6963 - accuracy: 0.6549
# Epoch 14/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6690 - accuracy: 0.6523
# Epoch 15/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6256 - accuracy: 0.6836
# Epoch 16/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6024 - accuracy: 0.6953
# Epoch 17/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6063 - accuracy: 0.6914
# Epoch 18/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6206 - accuracy: 0.6940
# Epoch 19/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6162 - accuracy: 0.6888
# Epoch 20/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6010 - accuracy: 0.6693
# Epoch 21/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5879 - accuracy: 0.7083
# Epoch 22/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6126 - accuracy: 0.6862
# Epoch 23/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6141 - accuracy: 0.6979
# Epoch 24/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6452 - accuracy: 0.6979
# Epoch 25/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5831 - accuracy: 0.6966
# Epoch 26/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.6043 - accuracy: 0.6966
# Epoch 27/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5786 - accuracy: 0.7057
# Epoch 28/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5710 - accuracy: 0.7253
# Epoch 29/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5780 - accuracy: 0.7122
# Epoch 30/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5973 - accuracy: 0.6914
# Epoch 31/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5640 - accuracy: 0.7188
# Epoch 32/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5704 - accuracy: 0.7161
# Epoch 33/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5538 - accuracy: 0.7383
# Epoch 34/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5853 - accuracy: 0.7031
# Epoch 35/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5617 - accuracy: 0.7096
# Epoch 36/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5977 - accuracy: 0.7109
# Epoch 37/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5770 - accuracy: 0.7279
# Epoch 38/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5530 - accuracy: 0.7292
# Epoch 39/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5596 - accuracy: 0.7396
# Epoch 40/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5542 - accuracy: 0.7227
# Epoch 41/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5614 - accuracy: 0.7331
# Epoch 42/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5734 - accuracy: 0.7031
# Epoch 43/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5611 - accuracy: 0.7240
# Epoch 44/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5415 - accuracy: 0.7305
# Epoch 45/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5684 - accuracy: 0.7214
# Epoch 46/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5440 - accuracy: 0.7305
# Epoch 47/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5613 - accuracy: 0.7292
# Epoch 48/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5461 - accuracy: 0.7292
# Epoch 49/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5637 - accuracy: 0.7201
# Epoch 50/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5735 - accuracy: 0.7096
# Epoch 51/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5472 - accuracy: 0.7331
# Epoch 52/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5380 - accuracy: 0.7370
# Epoch 53/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5396 - accuracy: 0.7357
# Epoch 54/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5292 - accuracy: 0.7578
# Epoch 55/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5444 - accuracy: 0.7357
# Epoch 56/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5459 - accuracy: 0.7357
# Epoch 57/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5677 - accuracy: 0.7096
# Epoch 58/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5759 - accuracy: 0.7305
# Epoch 59/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5646 - accuracy: 0.7253
# Epoch 60/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5958 - accuracy: 0.7096
# Epoch 61/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5690 - accuracy: 0.7148
# Epoch 62/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5267 - accuracy: 0.7422
# Epoch 63/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5310 - accuracy: 0.7474
# Epoch 64/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5416 - accuracy: 0.7383
# Epoch 65/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5450 - accuracy: 0.7383
# Epoch 66/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5562 - accuracy: 0.7487
# Epoch 67/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5803 - accuracy: 0.7083
# Epoch 68/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5327 - accuracy: 0.7513
# Epoch 69/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5488 - accuracy: 0.7370
# Epoch 70/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5181 - accuracy: 0.7578
# Epoch 71/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5332 - accuracy: 0.7448
# Epoch 72/150
# 77/77 [==============================] - 0s 1ms/step - loss: 0.5387 - accuracy: 0.7409
# Epoch 73/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5279 - accuracy: 0.7487
# Epoch 74/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5541 - accuracy: 0.7292
# Epoch 75/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5410 - accuracy: 0.7422
# Epoch 76/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5500 - accuracy: 0.7344
# Epoch 77/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5344 - accuracy: 0.7448
# Epoch 78/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5234 - accuracy: 0.7539
# Epoch 79/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5151 - accuracy: 0.7526
# Epoch 80/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5583 - accuracy: 0.7357
# Epoch 81/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5269 - accuracy: 0.7474
# Epoch 82/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5197 - accuracy: 0.7630
# Epoch 83/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5252 - accuracy: 0.7435
# Epoch 84/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5271 - accuracy: 0.7396
# Epoch 85/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5300 - accuracy: 0.7487
# Epoch 86/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5285 - accuracy: 0.7500
# Epoch 87/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5418 - accuracy: 0.7370
# Epoch 88/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5440 - accuracy: 0.7422
# Epoch 89/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5315 - accuracy: 0.7513
# Epoch 90/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5163 - accuracy: 0.7539
# Epoch 91/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5427 - accuracy: 0.7500
# Epoch 92/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 0.7708
# Epoch 93/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5004 - accuracy: 0.7682
# Epoch 94/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5162 - accuracy: 0.7500
# Epoch 95/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5121 - accuracy: 0.7630
# Epoch 96/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5007 - accuracy: 0.7630
# Epoch 97/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5255 - accuracy: 0.7526
# Epoch 98/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5032 - accuracy: 0.7656
# Epoch 99/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5189 - accuracy: 0.7552
# Epoch 100/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5649 - accuracy: 0.7370
# Epoch 101/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.7604
# Epoch 102/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5074 - accuracy: 0.7565
# Epoch 103/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5026 - accuracy: 0.7747
# Epoch 104/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4999 - accuracy: 0.7630
# Epoch 105/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4945 - accuracy: 0.7852
# Epoch 106/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5061 - accuracy: 0.7591
# Epoch 107/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5525 - accuracy: 0.7526
# Epoch 108/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5067 - accuracy: 0.7604
# Epoch 109/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5154 - accuracy: 0.7604
# Epoch 110/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5133 - accuracy: 0.7656
# Epoch 111/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5154 - accuracy: 0.7474
# Epoch 112/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4990 - accuracy: 0.7578
# Epoch 113/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5071 - accuracy: 0.7656
# Epoch 114/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4924 - accuracy: 0.7773
# Epoch 115/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4938 - accuracy: 0.7708
# Epoch 116/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5051 - accuracy: 0.7656
# Epoch 117/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5047 - accuracy: 0.7591
# Epoch 118/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5041 - accuracy: 0.7695
# Epoch 119/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4908 - accuracy: 0.7747
# Epoch 120/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4958 - accuracy: 0.7565
# Epoch 121/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5006 - accuracy: 0.7760
# Epoch 122/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4831 - accuracy: 0.7747
# Epoch 123/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5306 - accuracy: 0.7682
# Epoch 124/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4911 - accuracy: 0.7799
# Epoch 125/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5055 - accuracy: 0.7734
# Epoch 126/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5046 - accuracy: 0.7630
# Epoch 127/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4875 - accuracy: 0.7773
# Epoch 128/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4993 - accuracy: 0.7617
# Epoch 129/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4826 - accuracy: 0.7760
# Epoch 130/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5300 - accuracy: 0.7279
# Epoch 131/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4978 - accuracy: 0.7786
# Epoch 132/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4883 - accuracy: 0.7656
# Epoch 133/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5086 - accuracy: 0.7721
# Epoch 134/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4950 - accuracy: 0.7734
# Epoch 135/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4968 - accuracy: 0.7760
# Epoch 136/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5302 - accuracy: 0.7487
# Epoch 137/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4874 - accuracy: 0.7852
# Epoch 138/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4893 - accuracy: 0.7734
# Epoch 139/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5120 - accuracy: 0.7630
# Epoch 140/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4982 - accuracy: 0.7773
# Epoch 141/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4820 - accuracy: 0.7760
# Epoch 142/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4903 - accuracy: 0.7799
# Epoch 143/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5178 - accuracy: 0.7708
# Epoch 144/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4872 - accuracy: 0.7826
# Epoch 145/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4926 - accuracy: 0.7604
# Epoch 146/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.5029 - accuracy: 0.7630
# Epoch 147/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4802 - accuracy: 0.7799
# Epoch 148/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4801 - accuracy: 0.7839
# Epoch 149/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4860 - accuracy: 0.7747
# Epoch 150/150
# 77/77 [==============================] - 0s 2ms/step - loss: 0.4839 - accuracy: 0.7773

# %%
# evaluate the keras model
_, accuracy = model.evaluate(X, Y)
print('Accuracy: %.2f' % (accuracy*100))
# Out:
# 24/24 [==============================] - 0s 2ms/step - loss: 0.4811 - accuracy: 0.7878
# Accuracy: 78.78

# %%
# Plot model
plot_model(model, show_shapes=True, show_layer_names=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %%
#Plot history
plt.plot(history.history['loss'], label='binary cross entropy loss')
plt.xlabel('Epoch number')
plt.ylabel('Cross entropy loss')
# Out:
# Text(0, 0.5, 'Cross entropy loss')

# %% [markdown]
# ## Predictions

# %%
# make probability predictions with the model
predictions = model.predict(X)
# round predictions 
rounded = [round(x[0]) for x in predictions]
# Out:
# 24/24 [==============================] - 0s 2ms/step

# %% [markdown]
# # Task 1
# Create another model (give it a different name) with a slightly different architecture, e.g. with a different number of neurons in the two hidden layers. Specify how many neurons in each layer. Add an extra hidden layer.

# %%
#Please post your solution here.
#Feel free to add markdown and code cells as you need

# %% [markdown]
# # Task 2
#
# Split the data into a training set (80%) and a validation set (20%), by setting the *validation_split* parameter appropriately in the Keras model.

# %%
#Please post your solution here.
#Feel free to add markdown and code cells as you need

# %% [markdown]
# # Task 3
#
# Visualize the performance of your model during training by using the history dictionary object (part of model.fit()). Plot training loss and validation loss against Epoch.

# %%
#Please post your solution here.
#Feel free to add markdown and code cells as you need

# %% [markdown]
# # Task 4
#
# Using your model from *Task 1* change the activation functions and see how this affects training.

# %%
#Please post your solution here.
#Feel free to add markdown and code cells as you need

# %% [markdown]
# # Task 5
#
# Increase the number of epochs. See what happens.

# %%
#Please post your solution here.
#Feel free to add markdown and code cells as you need

# %% [markdown]
# # Task 6 (optional)
#
# Try similar steps for the multiclass tutorial:
#
# https://machinelearningmastery.com/multi-class-classification-tutorial-keras-deep-learning-library/
